# %%
import os
import math
import requests
import faiss
import numpy as np
import concurrent.futures
import re
import time

# %%
from datetime import date
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import PyPDFLoader
from langchain_ollama.embeddings import OllamaEmbeddings
from langchain_ollama.llms import OllamaLLM
from langchain.vectorstores import FAISS
from langchain.schema import Document
from langchain.chains import RetrievalQA

# %%
print("Alle Bibliotheken importiert und bereit.")
# Out:
# Alle Bibliotheken importiert und bereit.

# %%
MODEL_NAME = "deepseek-r1:7b"
INDEX_PATH = "faiss_index.faiss"
API_URL = "https://data.bka.gv.at/ris/api/v2.6/Landesrecht"
print(f"Konfiguration gesetzt: MODEL_NAME = {MODEL_NAME}, INDEX_PATH = '{INDEX_PATH}', API_URL = {API_URL}")
# Out:
# Konfiguration gesetzt: MODEL_NAME = deepseek-r1:7b, INDEX_PATH = 'faiss_index.faiss', API_URL = https://data.bka.gv.at/ris/api/v2.6/Landesrecht

# %%
embeddings = OllamaEmbeddings(model=MODEL_NAME)
llm = OllamaLLM(model=MODEL_NAME)
session = requests.Session()
print("Embeddings- und LLM-Objekte erstellt. Aktuelle Session wurde aufgerufen.")
# Out:
# Embeddings- und LLM-Objekte erstellt. Aktuelle Session wurde aufgerufen.

# %%
def fetch_and_parse_ris(ref):
    """
    1) Metadaten holen
    2) HTML-URL abrufen und Seite laden
    3) Mit BeautifulSoup nach dem <a>-Tag für das PDF suchen
    4) Absolute PDF-URL bauen
    5) PDF via PyPDFLoader einlesen und Text zurückliefern
    """
    lrKons = (
        ref.get("Data", {})
            .get("Metadaten", {})
            .get("Landesrecht", {})
            .get("LrKons", {})
    )
    html_url = lrKons.get("GesamteRechtsvorschriftUrl")
    if not html_url:
        return []

    try:
        resp = session.get(html_url, timeout=60)
        resp.raise_for_status()
        soup = BeautifulSoup(resp.text, "html.parser")

        a_pdf = soup.find(
            "a",
            href=re.compile(r"\.pdf$"),
            title=lambda t: t and "PDF-Dokument" in t
        )
        if not a_pdf or not a_pdf.has_attr("href"):
            print(f"PDF-Link nicht gefunden in {html_url}")
            return []

        pdf_path = a_pdf["href"]
        pdf_url = urljoin("https://www.ris.bka.gv.at", pdf_path)

        print(f"Lade PDF: {pdf_url}")
        loader = PyPDFLoader(pdf_url)
        docs = loader.load()
        print(f"{len(docs)} Seiten geladen von {pdf_url}")
        return [(pdf_url, doc.page_content) for doc in docs]

    except Exception as e:
        print(f"Fehler beim Verarbeiten von {html_url}: {e}")
        return []

# %%
heute  = date.today().isoformat()
params = {
    "Applikation": "LrKons",
    "Bundesland_SucheInSalzburg": "true",
    "Sortierung_SortDirection": "Descending",
    "DokumenteProSeite": "Ten",
    "Fassung_FassungVom": heute
}
resp = session.get(API_URL, params=params)
resp.raise_for_status()
data = resp.json()
hits = int(data["OgdSearchResult"]["OgdDocumentResults"]["Hits"]["#text"])
page_size = int(data["OgdSearchResult"]["OgdDocumentResults"]["Hits"]["@pageSize"])
total = math.ceil(hits / page_size)

# %%
all_refs = []
# for page in range(1, total+1):
for page in range(1, 2):
    params["Seitennummer"] = page
    resp = session.get(API_URL, params=params); resp.raise_for_status()
    docs = resp.json()["OgdSearchResult"]["OgdDocumentResults"]["OgdDocumentReference"]
    all_refs.extend(docs if isinstance(docs, list) else [docs])
print(f"Insgesamt {len(all_refs)} Dokumentreferenzen geladen.")
# Out:
# Insgesamt 10 Dokumentreferenzen geladen.

# %%
all_sections = []
with concurrent.futures.ThreadPoolExecutor(max_workers=8) as pool:
    futures = [pool.submit(fetch_and_parse_ris, ref) for ref in all_refs]
    for fut in concurrent.futures.as_completed(futures):
        all_sections.extend(fut.result() or [])
print(f"Insgesamt {len(all_sections)} Textabschnitte aus PDFs extrahiert.")
# Out:
# Lade PDF: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001469/Zweitwohnung-Beschr%c3%a4nkungsgemeinden-Verordnung%202024%2c%20Fassung%20vom%2017.06.2025.pdf
# Lade PDF: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001469/Zweitwohnung-Beschr%c3%a4nkungsgemeinden-Verordnung%202024%2c%20Fassung%20vom%2017.06.2025.pdf
# Lade PDF: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001469/Zweitwohnung-Beschr%c3%a4nkungsgemeinden-Verordnung%202024%2c%20Fassung%20vom%2017.06.2025.pdf
# Lade PDF: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Lade PDF: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Lade PDF: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Lade PDF: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Lade PDF: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# 1 Seiten geladen von https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001469/Zweitwohnung-Beschr%c3%a4nkungsgemeinden-Verordnung%202024%2c%20Fassung%20vom%2017.06.2025.pdf
# Lade PDF: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# 7 Seiten geladen von https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Lade PDF: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# 1 Seiten geladen von https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001469/Zweitwohnung-Beschr%c3%a4nkungsgemeinden-Verordnung%202024%2c%20Fassung%20vom%2017.06.2025.pdf
# 1 Seiten geladen von https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001469/Zweitwohnung-Beschr%c3%a4nkungsgemeinden-Verordnung%202024%2c%20Fassung%20vom%2017.06.2025.pdf
# 7 Seiten geladen von https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# 7 Seiten geladen von https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# 7 Seiten geladen von https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# 7 Seiten geladen von https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# 7 Seiten geladen von https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# 7 Seiten geladen von https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Insgesamt 52 Textabschnitte aus PDFs extrahiert.

# %%
docs = [Document(page_content=text, metadata={"source_url": url})
        for url, text in all_sections]
print(f"Erstellt {len(docs)} LangChain-Dokumente.")
# Out:
# Erstellt 52 LangChain-Dokumente.

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1200, chunk_overlap=200)
chunked_docs = splitter.split_documents(docs)
print(f"Anzahl Chunks: {len(chunked_docs)}")
# Out:
# Anzahl Chunks: 156

# %%
for i, chunk in enumerate(chunked_docs):
    source = chunk.metadata["source_url"]
    text = chunk.page_content
    snippet = text[:500].replace("\n", " ")

    print(f"\n--- Chunk {i+1}/{len(chunked_docs)} ---")
    print(f"Quelle: {source}")
    print(f"Inhalt (erstes 500 Zeichen): {snippet} …")
    print(f"Länge dieses Chunks: {len(text)} Zeichen")
    print("--- Ende Chunk ---", flush=True)
# Out:
# --- Chunk 1/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001469/Zweitwohnung-Beschr%c3%a4nkungsgemeinden-Verordnung%202024%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen): Landesrecht Salzburg  www.ris.bka.gv.at Seite 1 von 1  Gesamte Rechtsvorschrift für Zweitwohnung -Beschränkungsgemeinden-Verordnung  2024, Fassung vom 17.06.2025  Langtitel  Verordnung der Salzburger Landessregierung vom 27. Februar 2024, mit der die Zweitwohnung- Beschränkungsgemeinden im Land Salzburg bestimmt werden (Zweitwohnung - Beschränkungsgemeinden-Verordnung 2024)  StF: LGBl Nr 26/2024  Präambel/Promulgationsklausel  Auf Grund des §  31 Abs  1 des Salzburger Raumordnungsgesetzes  2009  …
# Länge dieses Chunks: 1135 Zeichen
# --- Ende Chunk ---
#
# --- Chunk 2/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001469/Zweitwohnung-Beschr%c3%a4nkungsgemeinden-Verordnung%202024%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen): 2. im Tennengau die Gemeinden: Abtenau, Adnet, Annaberg im Lammertal, Bad Vigaun, Goll ing  an der Salzach, Kuchl, Krispl, Rußbach am Pass Gschütt, Scheffau am Tennengebirge und St.  Koloman;   3. im Pongau die Gemeinden: Altenmarkt im Pongau, Bad Gastein, Bad Hofgastein, Bischofshofen,  Dorfgastein, Eben im Pongau, Filzmoos, Flachau, Forstau, G oldegg, Großarl, Hüttau, Hüttschlag,  Kleinarl, Mühlbach am Hochkönig, Pfarrwerfen, Radstadt, St. Johann im Pongau, St. Martin am  Tennengebirge, St. Ve …
# Länge dieses Chunks: 1171 Zeichen
# --- Ende Chunk ---
#
# --- Chunk 3/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001469/Zweitwohnung-Beschr%c3%a4nkungsgemeinden-Verordnung%202024%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen): 5. im Lungau die Gemeinden: Göriach, Lessach, Mariapfarr, Mauterndorf, Muhr, Ramingstein, St.  Andrä im Lungau, St. Margarethen im Lungau , St. Michael im Lungau, Tamsweg, Thomatal,  Tweng, Weißpriach und Zederhaus.  Inkrafttreten  § 2  Diese Verordnung tritt mit 1.  März 2024 in Kraft. Gleichzeitig tritt die Verordnung der Salzburger  Landessregierung vom 10.  Dezember 2018, mit der die Zweitwohnung-Beschränkungsgemeinden im  Land Salzburg bestimmt werden (Zweitwohnung -Beschränkungsgemeinden-V …
# Länge dieses Chunks: 542 Zeichen
# --- Ende Chunk ---
#
# --- Chunk 4/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen): Landesrecht Salzburg  www.ris.bka.gv.at Seite 1 von 7  Gesamte Rechtsvorschrift für Zweitwohnsitz - und Wohnungsleerstandsabgabengesetz,  Fassung vom 17.06.2025  Langtitel  Gesetz vom 6. Juli 2022 zur Erhebung von Kommunalabgaben für Zweitwohnsitze und  Wohnungsleerstände (Zweitwohnsitz- und Wohnungsleerstandsabgabengesetz – ZWAG)  StF: LGBl Nr 71/2022 (Blg LT 16. GP: RV 507, AB 550, jeweils 5. Sess)  Änderung  LGBl Nr 6/2024 (Blg LT 17. GP: IA 102, AB 126, jeweils 2. Sess)  Präambel/Promulgatio …
# Länge dieses Chunks: 1195 Zeichen
# --- Ende Chunk ---
#
# --- Chunk 5/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen): § 11 Abgabenschuldner   § 12 Bemessungsgrundlagen   § 13 Höhe der Abgabe   § 14 Entstehung des Abgabenanspruchs, Anzeigeverpflichtungen  4. Abschnitt  Datenschutzrechtliche Bestimmungen   § 15 Datenverarbeitung   § 16 Datenerhebung  5. Abschnitt  Schlussbestimmungen   § 17 Strafbestimmungen   § 18 Verweisungen auf Bundes- und Unionsrecht   § 19 Inkrafttreten   § 20 Inkrafttreten novellierter Bestimmungen …
# Länge dieses Chunks: 407 Zeichen
# --- Ende Chunk ---
#
# --- Chunk 6/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen): Landesrecht Salzburg  www.ris.bka.gv.at Seite 2 von 7  Text  1. Abschnitt  Gemeinsame Bestimmungen  Ermächtigung zur Ausschreibung  § 1  Die Gemeinden werden ermächtigt, auf Grund eines Beschlusses der Gemeindevertretung (in der  Stadt Salzburg des Gemeinderats) als ausschließliche Gemeindeabgabe zu erheben:   1. eine Abgabe auf Zweitwohnsitze (Kommunalabgabe Zweitwohnsitz);   2. eine Abgabe auf Wohnungen ohne Wohnsitz (Kommunalabgabe Wohnungsleerstand).   Eigener Wirkungsbereich, Abgabenbehörde …
# Länge dieses Chunks: 1124 Zeichen
# --- Ende Chunk ---
#
# --- Chunk 7/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen):
ieses Gesetzes verarbeitet werden, auch in folgenden Verfahren verarbeiten:    1. in Verfahren betreffend Zweitwohnungen nach den bau -, raumordnungs - und  grundverkehrsrechtlichen Bestimmungen des Landes;   2. in Verfahren betreffend Zweckentfremdungen von Wohnunge …
# Länge dieses Chunks: 1145 Zeichen
# --- Ende Chunk ---
#
# --- Chunk 153/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen): verarbeiten.  (4) Die nach Abs  1 Verantwortlichen haben personenbezogene Daten zu löschen, sobald diese für  die Erfüllung der ihnen im Zusammenhang m it diesem Gesetz obliegenden Aufgaben nicht mehr benötigt  werden.  Datenerhebung  § 16  (1) Für Zwecke der Abgabenerhebung sind die Abgabenbehörden unbeschadet ihrer Befugnisse nach  der BAO berechtigt auf automationsunterstütztem Weg:   1. in Bezug auf die Kom munalabgabe Wohnungsleerstand Art und Anzahl der Wohnsitze in einer  Wohnung sowie di …
# Länge dieses Chunks: 1165 Zeichen
# --- Ende Chunk ---
#
# --- Chunk 154/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen): (2) Zum Zweck der Feststellung eines Wohnsitzes gemäß §  3 Abs  3 haben auf Anfrage der  Abgabenbehörde die Versorgungs - oder Entsorgungsunternehmen die vorhandenen Verbrauchsdaten für  Wasser und Energie für die betreffende Wohnung im Abgabenzeitraum zu übermitteln und die Erbringer  von Postdiensten oder von elektronischen Zustelldiensten die zur Beurteilung der Nutzung erforderlichen  Auskünfte zu erteilen.  5. Abschnitt  Schlussbestimmungen  Strafbestimmungen  § 17  (1) Eine Verwaltungsüber …
# Länge dieses Chunks: 1160 Zeichen
# --- Ende Chunk ---
#
# --- Chunk 155/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen): 54/2021;   2. Richtwertgesetz – RichtwG, BGBl Nr 800/1993, zuletzt geändert durch das Gesetz BGBl I Nr  59/2021;   3. Wohnungseigentumsgesetz 2002 – WEG 2002, BGBl I Nr 70/2002, zuletzt geändert durch das  Gesetz BGBl I Nr 222/2021. …
# Länge dieses Chunks: 232 Zeichen
# --- Ende Chunk ---
#
# --- Chunk 156/156 ---
# Quelle: https://www.ris.bka.gv.at/GeltendeFassung/LrSbg/20001389/%20ZWAG%2c%20Fassung%20vom%2017.06.2025.pdf
# Inhalt (erstes 500 Zeichen): Landesrecht Salzburg  www.ris.bka.gv.at Seite 7 von 7  (2) Dieses Gesetz verweist auf die Verordnung (EU) 2016/679 zum Schutz natürlicher Personen bei  der Verarbeitung personenbezogener Daten, zum freien Datenverkehr und zur Aufhebung der Richtlinie  95/46/EG (Datenschutz -Grundverordnung), ABl Nr L  119 vom 4.  Mai 2016 S  1, in der Fassung der  Berichtigung ABl Nr L 74 vom 4. März 2021 S 35.  Inkrafttreten  § 19  (1) Dieses Gesetz tritt mit 1. Jänner 2023 in Kraft.  (2) Verordnungen nach dies …
# Länge dieses Chunks: 945 Zeichen
# --- Ende Chunk ---

# %%
class DebugOllamaEmbeddings(OllamaEmbeddings):
    def embed_documents(self, texts: list[str]) -> list[list[float]]:
        total = len(texts)
        results = []
        for i, text in enumerate(texts, start=1):
            start_save_sg = time.perf_counter()
            print(f"Verarbeite Chunk {i}/{total}")
            emb = super().embed_documents([text])[0]
            results.append(emb)
            end_save_sg = time.perf_counter()
            print(f"Chunk {i} gespeichert in {end_save_sg - start_save_sg:.2f} Sekunden.")
        return results

# %%
embeddings = DebugOllamaEmbeddings(model=MODEL_NAME)

# %%
start_embed = time.perf_counter()
print(f"Starte Embedding von {len(chunked_docs)} Chunks …")
# vector_store = FAISS.from_documents(chunked_docs, embeddings)
vector_store = FAISS.from_documents(chunked_docs, embeddings)
end_embed = time.perf_counter()
print(f"Embedding abgeschlossen in {end_embed - start_embed:.2f} Sekunden.")

start_save = time.perf_counter()
print("Speichere FAISS-Index …")
vector_store.save_local(INDEX_PATH)
end_save = time.perf_counter()
print(f"FAISS-Index gespeichert unter '{INDEX_PATH}' in {end_save - start_save:.2f} Sekunden.")
print(f"Gesamtzeit für Embedding + Speichern: {end_save - start_embed:.2f} Sekunden.")
# Out:
# Starte Embedding von 156 Chunks …
# Verarbeite Chunk 1/156
# Chunk 1 gespeichert in 22.91 Sekunden.
# Verarbeite Chunk 2/156
# Chunk 2 gespeichert in 19.75 Sekunden.
# Verarbeite Chunk 3/156
# Chunk 3 gespeichert in 8.62 Sekunden.
# Verarbeite Chunk 4/156
# Chunk 4 gespeichert in 20.36 Sekunden.
# Verarbeite Chunk 5/156
# Chunk 5 gespeichert in 6.44 Sekunden.
# Verarbeite Chunk 6/156
# Chunk 6 gespeichert in 16.30 Sekunden.
# Verarbeite Chunk 7/156
# Chunk 7 gespeichert in 16.28 Sekunden.
# Verarbeite Chunk 8/156
# Chunk 8 gespeichert in 11.88 Sekunden.
# Verarbeite Chunk 9/156
# Chunk 9 gespeichert in 15.54 Sekunden.
# Verarbeite Chunk 10/156
# Chunk 10 gespeichert in 19.56 Sekunden.
# Verarbeite Chunk 11/156
# Chunk 11 gespeichert in 15.71 Sekunden.
# Verarbeite Chunk 12/156
# Chunk 12 gespeichert in 7.72 Sekunden.
# Verarbeite Chunk 13/156
# Chunk 13 gespeichert in 15.39 Sekunden.
# Verarbeite Chunk 14/156
# Chunk 14 gespeichert in 15.77 Sekunden.
# Verarbeite Chunk 15/156
# Chunk 15 gespeichert in 16.27 Sekunden.
# Verarbeite Chunk 16/156
# Chunk 16 gespeichert in 4.80 Sekunden.
# Verarbeite Chunk 17/156
# Chunk 17 gespeichert in 20.57 Sekunden.
# Verarbeite Chunk 18/156
# Chunk 18 gespeichert in 16.25 Sekunden.
# Verarbeite Chunk 19/156
# Chunk 19 gespeichert in 12.86 Sekunden.
# Verarbeite Chunk 20/156
# Chunk 20 gespeichert in 15.69 Sekunden.
# Verarbeite Chunk 21/156
# Chunk 21 gespeichert in 15.47 Sekunden.
# Verarbeite Chunk 22/156
# Chunk 22 gespeichert in 17.93 Sekunden.
# Verarbeite Chunk 23/156
# Chunk 23 gespeichert in 4.14 Sekunden.
# Verarbeite Chunk 24/156
# Chunk 24 gespeichert in 14.94 Sekunden.
# Verarbeite Chunk 25/156
# Chunk 25 gespeichert in 20.14 Sekunden.
# Verarbeite Chunk 26/156
# Chunk 26 gespeichert in 20.11 Sekunden.
# Verarbeite Chunk 27/156
# Chunk 27 gespeichert in 9.07 Sekunden.
# Verarbeite Chunk 28/156
# Chunk 28 gespeichert in 19.79 Sekunden.
# Verarbeite Chunk 29/156
# Chunk 29 gespeichert in 19.95 Sekunden.
# Verarbeite Chunk 30/156
# Chunk 30 gespeichert in 8.97 Sekunden.
# Verarbeite Chunk 31/156
# Chunk 31 gespeichert in 21.49 Sekunden.
# Verarbeite Chunk 32/156
# Chunk 32 gespeichert in 6.43 Sekunden.
# Verarbeite Chunk 33/156
# Chunk 33 gespeichert in 16.26 Sekunden.
# Verarbeite Chunk 34/156
# Chunk 34 gespeichert in 16.54 Sekunden.
# Verarbeite Chunk 35/156
# Chunk 35 gespeichert in 11.57 Sekunden.
# Verarbeite Chunk 36/156
# Chunk 36 gespeichert in 15.73 Sekunden.
# Verarbeite Chunk 37/156
# Chunk 37 gespeichert in 19.52 Sekunden.
# Verarbeite Chunk 38/156
# Chunk 38 gespeichert in 15.98 Sekunden.
# Verarbeite Chunk 39/156
# Chunk 39 gespeichert in 7.62 Sekunden.
# Verarbeite Chunk 40/156
# Chunk 40 gespeichert in 15.47 Sekunden.
# Verarbeite Chunk 41/156
# Chunk 41 gespeichert in 15.94 Sekunden.
# Verarbeite Chunk 42/156
# Chunk 42 gespeichert in 16.30 Sekunden.
# Verarbeite Chunk 43/156
# Chunk 43 gespeichert in 4.71 Sekunden.
# Verarbeite Chunk 44/156
# Chunk 44 gespeichert in 20.99 Sekunden.
# Verarbeite Chunk 45/156
# Chunk 45 gespeichert in 16.20 Sekunden.
# Verarbeite Chunk 46/156
# Chunk 46 gespeichert in 13.20 Sekunden.
# Verarbeite Chunk 47/156
# Chunk 47 gespeichert in 15.61 Sekunden.
# Verarbeite Chunk 48/156
# Chunk 48 gespeichert in 15.60 Sekunden.
# Verarbeite Chunk 49/156
# Chunk 49 gespeichert in 17.70 Sekunden.
# Verarbeite Chunk 50/156
# Chunk 50 gespeichert in 5.40 Sekunden.
# Verarbeite Chunk 51/156
# Chunk 51 gespeichert in 15.09 Sekunden.
# Verarbeite Chunk 52/156
# Chunk 52 gespeichert in 21.35 Sekunden.
# Verarbeite Chunk 53/156
# Chunk 53 gespeichert in 6.52 Sekunden.
# Verarbeite Chunk 54/156
# Chunk 54 gespeichert in 16.27 Sekunden.
# Verarbeite Chunk 55/156
# Chunk 55 gespeichert in 16.56 Sekunden.
# Verarbeite Chunk 56/156
# Chunk 56 gespeichert in 11.91 Sekunden.
# Verarbeite Chunk 57/156
# Chunk 57 gespeichert in 15.79 Sekunden.
# Verarbeite Chunk 58/156
# Chunk 58 gespeichert in 19.40 Sekunden.
# Verarbeite Chunk 59/156
# Chunk 59 gespeichert in 16.04 Sekunden.
# Verarbeite Chunk 60/156
# Chunk 60 gespeichert in 7.66 Sekunden.
# Verarbeite Chunk 61/156
# Chunk 61 gespeichert in 15.37 Sekunden.
# Verarbeite Chunk 62/156
# Chunk 62 gespeichert in 15.94 Sekunden.
# Verarbeite Chunk 63/156
# Chunk 63 gespeichert in 16.38 Sekunden.
# Verarbeite Chunk 64/156
# Chunk 64 gespeichert in 4.76 Sekunden.
# Verarbeite Chunk 65/156
# Chunk 65 gespeichert in 20.73 Sekunden.
# Verarbeite Chunk 66/156
# Chunk 66 gespeichert in 15.70 Sekunden.
# Verarbeite Chunk 67/156
# Chunk 67 gespeichert in 12.76 Sekunden.
# Verarbeite Chunk 68/156
# Chunk 68 gespeichert in 16.25 Sekunden.
# Verarbeite Chunk 69/156
# Chunk 69 gespeichert in 15.63 Sekunden.
# Verarbeite Chunk 70/156
# Chunk 70 gespeichert in 18.07 Sekunden.
# Verarbeite Chunk 71/156
# Chunk 71 gespeichert in 5.56 Sekunden.
# Verarbeite Chunk 72/156
# Chunk 72 gespeichert in 15.04 Sekunden.
# Verarbeite Chunk 73/156
# Chunk 73 gespeichert in 21.38 Sekunden.
# Verarbeite Chunk 74/156
# Chunk 74 gespeichert in 6.43 Sekunden.
# Verarbeite Chunk 75/156
# Chunk 75 gespeichert in 16.33 Sekunden.
# Verarbeite Chunk 76/156
# Chunk 76 gespeichert in 16.38 Sekunden.
# Verarbeite Chunk 77/156
# Chunk 77 gespeichert in 12.01 Sekunden.
# Verarbeite Chunk 78/156
# Chunk 78 gespeichert in 15.40 Sekunden.
# Verarbeite Chunk 79/156
# Chunk 79 gespeichert in 19.80 Sekunden.
# Verarbeite Chunk 80/156
# Chunk 80 gespeichert in 16.01 Sekunden.
# Verarbeite Chunk 81/156
# Chunk 81 gespeichert in 7.74 Sekunden.
# Verarbeite Chunk 82/156
# Chunk 82 gespeichert in 15.06 Sekunden.
# Verarbeite Chunk 83/156
# Chunk 83 gespeichert in 15.83 Sekunden.
# Verarbeite Chunk 84/156
# Chunk 84 gespeichert in 16.34 Sekunden.
# Verarbeite Chunk 85/156
# Chunk 85 gespeichert in 4.77 Sekunden.
# Verarbeite Chunk 86/156
# Chunk 86 gespeichert in 20.85 Sekunden.
# Verarbeite Chunk 87/156
# Chunk 87 gespeichert in 16.35 Sekunden.
# Verarbeite Chunk 88/156
# Chunk 88 gespeichert in 12.92 Sekunden.
# Verarbeite Chunk 89/156
# Chunk 89 gespeichert in 15.45 Sekunden.
# Verarbeite Chunk 90/156
# Chunk 90 gespeichert in 15.60 Sekunden.
# Verarbeite Chunk 91/156
# Chunk 91 gespeichert in 16.36 Sekunden.
# Verarbeite Chunk 92/156
# Chunk 92 gespeichert in 5.41 Sekunden.
# Verarbeite Chunk 93/156
# Chunk 93 gespeichert in 14.96 Sekunden.
# Verarbeite Chunk 94/156
# Chunk 94 gespeichert in 21.32 Sekunden.
# Verarbeite Chunk 95/156
# Chunk 95 gespeichert in 6.43 Sekunden.
# Verarbeite Chunk 96/156
# Chunk 96 gespeichert in 16.41 Sekunden.
# Verarbeite Chunk 97/156
# Chunk 97 gespeichert in 16.53 Sekunden.
# Verarbeite Chunk 98/156
# Chunk 98 gespeichert in 11.77 Sekunden.
# Verarbeite Chunk 99/156
# Chunk 99 gespeichert in 15.83 Sekunden.
# Verarbeite Chunk 100/156
# Chunk 100 gespeichert in 19.48 Sekunden.
# Verarbeite Chunk 101/156
# Chunk 101 gespeichert in 15.91 Sekunden.
# Verarbeite Chunk 102/156
# Chunk 102 gespeichert in 7.76 Sekunden.
# Verarbeite Chunk 103/156
# Chunk 103 gespeichert in 15.44 Sekunden.
# Verarbeite Chunk 104/156
# Chunk 104 gespeichert in 15.73 Sekunden.
# Verarbeite Chunk 105/156
# Chunk 105 gespeichert in 15.94 Sekunden.
# Verarbeite Chunk 106/156
# Chunk 106 gespeichert in 4.75 Sekunden.
# Verarbeite Chunk 107/156
# Chunk 107 gespeichert in 20.39 Sekunden.
# Verarbeite Chunk 108/156
# Chunk 108 gespeichert in 16.33 Sekunden.
# Verarbeite Chunk 109/156
# Chunk 109 gespeichert in 12.87 Sekunden.
# Verarbeite Chunk 110/156
# Chunk 110 gespeichert in 15.76 Sekunden.
# Verarbeite Chunk 111/156
# Chunk 111 gespeichert in 15.51 Sekunden.
# Verarbeite Chunk 112/156
# Chunk 112 gespeichert in 16.07 Sekunden.
# Verarbeite Chunk 113/156
# Chunk 113 gespeichert in 5.33 Sekunden.
# Verarbeite Chunk 114/156
# Chunk 114 gespeichert in 15.01 Sekunden.
# Verarbeite Chunk 115/156
# Chunk 115 gespeichert in 21.07 Sekunden.
# Verarbeite Chunk 116/156
# Chunk 116 gespeichert in 6.14 Sekunden.
# Verarbeite Chunk 117/156
# Chunk 117 gespeichert in 15.61 Sekunden.
# Verarbeite Chunk 118/156
# Chunk 118 gespeichert in 16.11 Sekunden.
# Verarbeite Chunk 119/156
# Chunk 119 gespeichert in 11.82 Sekunden.
# Verarbeite Chunk 120/156
# Chunk 120 gespeichert in 15.68 Sekunden.
# Verarbeite Chunk 121/156
# Chunk 121 gespeichert in 19.05 Sekunden.
# Verarbeite Chunk 122/156
# Chunk 122 gespeichert in 15.95 Sekunden.
# Verarbeite Chunk 123/156
# Chunk 123 gespeichert in 7.71 Sekunden.
# Verarbeite Chunk 124/156
# Chunk 124 gespeichert in 15.28 Sekunden.
# Verarbeite Chunk 125/156
# Chunk 125 gespeichert in 15.97 Sekunden.
# Verarbeite Chunk 126/156
# Chunk 126 gespeichert in 16.17 Sekunden.
# Verarbeite Chunk 127/156
# Chunk 127 gespeichert in 4.75 Sekunden.
# Verarbeite Chunk 128/156
# Chunk 128 gespeichert in 20.42 Sekunden.
# Verarbeite Chunk 129/156
# Chunk 129 gespeichert in 16.03 Sekunden.
# Verarbeite Chunk 130/156
# Chunk 130 gespeichert in 13.09 Sekunden.
# Verarbeite Chunk 131/156
# Chunk 131 gespeichert in 15.58 Sekunden.
# Verarbeite Chunk 132/156
# Chunk 132 gespeichert in 15.40 Sekunden.
# Verarbeite Chunk 133/156
# Chunk 133 gespeichert in 17.54 Sekunden.
# Verarbeite Chunk 134/156
# Chunk 134 gespeichert in 5.39 Sekunden.
# Verarbeite Chunk 135/156
# Chunk 135 gespeichert in 15.12 Sekunden.
# Verarbeite Chunk 136/156
# Chunk 136 gespeichert in 21.07 Sekunden.
# Verarbeite Chunk 137/156
# Chunk 137 gespeichert in 6.54 Sekunden.
# Verarbeite Chunk 138/156
# Chunk 138 gespeichert in 16.36 Sekunden.
# Verarbeite Chunk 139/156
# Chunk 139 gespeichert in 16.42 Sekunden.
# Verarbeite Chunk 140/156
# Chunk 140 gespeichert in 11.73 Sekunden.
# Verarbeite Chunk 141/156
# Chunk 141 gespeichert in 15.71 Sekunden.
# Verarbeite Chunk 142/156
# Chunk 142 gespeichert in 19.63 Sekunden.
# Verarbeite Chunk 143/156
# Chunk 143 gespeichert in 15.91 Sekunden.
# Verarbeite Chunk 144/156
# Chunk 144 gespeichert in 7.70 Sekunden.
# Verarbeite Chunk 145/156
# Chunk 145 gespeichert in 15.34 Sekunden.
# Verarbeite Chunk 146/156
# Chunk 146 gespeichert in 15.95 Sekunden.
# Verarbeite Chunk 147/156
# Chunk 147 gespeichert in 16.24 Sekunden.
# Verarbeite Chunk 148/156
# Chunk 148 gespeichert in 4.81 Sekunden.
# Verarbeite Chunk 149/156
# Chunk 149 gespeichert in 20.51 Sekunden.
# Verarbeite Chunk 150/156
# Chunk 150 gespeichert in 16.14 Sekunden.
# Verarbeite Chunk 151/156
# Chunk 151 gespeichert in 13.24 Sekunden.
# Verarbeite Chunk 152/156
# Chunk 152 gespeichert in 15.18 Sekunden.
# Verarbeite Chunk 153/156
# Chunk 153 gespeichert in 15.66 Sekunden.
# Verarbeite Chunk 154/156
# Chunk 154 gespeichert in 16.70 Sekunden.
# Verarbeite Chunk 155/156
# Chunk 155 gespeichert in 4.76 Sekunden.
# Verarbeite Chunk 156/156
# Chunk 156 gespeichert in 15.03 Sekunden.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 print(f"Starte Embedding von {len(chunked_docs)} Chunks …")
#       3 # vector_store = FAISS.from_documents(chunked_docs, embeddings)
# ----> 4 vector_store = FAISS.from_documents(chunked_docs, embeddings, batch_size=32)
#       5 end_embed = time.perf_counter()
#       6 print(f"Embedding abgeschlossen in {end_embed - start_embed:.2f} Sekunden.")
#
# File ~\Documents\GitHub\RISolver\venv\Lib\site-packages\langchain_core\vectorstores\base.py:848, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     845     if any(ids):
#     846         kwargs["ids"] = ids
# --> 848 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~\Documents\GitHub\RISolver\venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:1044, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1025 """Construct FAISS wrapper from raw documents.
#    1026
#    1027 This is a user friendly interface that:
#    (...)   1041         faiss = FAISS.from_texts(texts, embeddings)
#    1042 """
#    1043 embeddings = embedding.embed_documents(texts)
# -> 1044 return cls.__from(
#    1045     texts,
#    1046     embeddings,
#    1047     embedding,
#    1048     metadatas=metadatas,
#    1049     ids=ids,
#    1050     **kwargs,
#    1051 )
#
# File ~\Documents\GitHub\RISolver\venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:1004, in FAISS.__from(cls, texts, embeddings, embedding, metadatas, ids, normalize_L2, distance_strategy, **kwargs)
#    1002 docstore = kwargs.pop("docstore", InMemoryDocstore())
#    1003 index_to_docstore_id = kwargs.pop("index_to_docstore_id", {})
# -> 1004 vecstore = cls(
#    1005     embedding,
#    1006     index,
#    1007     docstore,
#    1008     index_to_docstore_id,
#    1009     normalize_L2=normalize_L2,
#    1010     distance_strategy=distance_strategy,
#    1011     **kwargs,
#    1012 )
#    1013 vecstore.__add(texts, embeddings, metadatas=metadatas, ids=ids)
#    1014 return vecstore
#
# TypeError: FAISS.__init__() got an unexpected keyword argument 'batch_size'

# %%
query = "Welche Gemeinden im Pongau sind Zweitwohnung-Beschränkungsgemeinden?"

# %%
results = vector_store.similarity_search_with_score(query, k=10)
print("\nTop-10 ähnliche Chunks für die Query:")
for rank, (doc, score) in enumerate(results, start=1):
    print(f"{rank}. Score={score:.2f}, Quelle={doc.metadata['source_url']}")
    print(">", doc.page_content[:120].replace("\n"," "), "…\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 results = vector_store.similarity_search_with_score(query, k=10)
#       2 print("\nTop-10 ähnliche Chunks für die Query:")
#       3 for rank, (doc, score) in enumerate(results, start=1):
#
# NameError: name 'vector_store' is not defined

# %%
retriever = vector_store.as_retriever(search_kwargs={"k":10})
qa_chain = RetrievalQA.from_chain_type(
    llm=llm, chain_type="stuff", retriever=retriever
)

# %%
answer = qa_chain.run(query)
print("\nAntwort:", answer)
